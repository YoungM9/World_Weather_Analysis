# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size =2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size =2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 754

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c48290f145f9a922842519fc7b6bc24c

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 1 | svetlyy
# Processing Record 3 of Set 1 | clifton
# Processing Record 4 of Set 1 | sitka
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | cabo san lucas
# Processing Record 7 of Set 1 | lorengau
# Processing Record 8 of Set 1 | faanui
# Processing Record 9 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 1 | mossendjo
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | chernyshevskiy
# Processing Record 13 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 1 | pevek
# Processing Record 15 of Set 1 | namtsy
# Processing Record 16 of Set 1 | gewane
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | severo-kurilsk
# Processing Record 19 of Set 1 | codrington
# Processing Record 20 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 1 | mahebourg
# Processing Record 22 of Set 1 | bambous virieux
# Processing Record 23 of Set 1 | brandfort
# Processing Record 24 of Set 1 | llanes
# Processing Record 25 of Set 1 | torbay
# Processing Record 26 of Set 1 | port macquarie
# Processing Record 27 of Set 1 | upernavik
# Processing Record 28 of Set 1 | tautira
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | verkhoyansk
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | san quintin
# Processing Record 37 of Set 1 | olafsvik
# Processing Record 38 of Set 1 | east london
# Processing Record 39 of Set 1 | kamariotissa
# Processing Record 40 of Set 1 | coracora
# Processing Record 41 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 1 | udachnyy
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 1 | norman wells
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | dunedin
# Processing Record 48 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 1 | hovd
# Processing Record 50 of Set 1 | putina
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 2 of Set 2 | dingle
# Processing Record 3 of Set 2 | ronneby
# Processing Record 4 of Set 2 | yar-sale
# Processing Record 5 of Set 2 | castro
# Processing Record 6 of Set 2 | sisimiut
# Processing Record 7 of Set 2 | verkhnevilyuysk
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | shingu
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | clyde river
# Processing Record 12 of Set 2 | hamilton
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | guerrero negro
# Processing Record 15 of Set 2 | venado tuerto
# Processing Record 16 of Set 2 | taitung
# Processing Record 17 of Set 2 | winneba
# Processing Record 18 of Set 2 | taoudenni
# Processing Record 19 of Set 2 | ostersund
# Processing Record 20 of Set 2 | provost
# Processing Record 21 of Set 2 | kavaratti
# Processing Record 22 of Set 2 | ushuaia
# Processing Record 23 of Set 2 | rikitea
# Processing Record 24 of Set 2 | port keats
# Processing Record 25 of Set 2 | riyadh
# Processing Record 26 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 2 | natchitoches
# Processing Record 28 of Set 2 | saldanha
# Processing Record 29 of Set 2 | butaritari
# Processing Record 30 of Set 2 | fuente de oro
# Processing Record 31 of Set 2 | jhalrapatan
# Processing Record 32 of Set 2 | saint-leu
# Processing Record 33 of Set 2 | hithadhoo
# Processing Record 34 of Set 2 | porto nacional
# Processing Record 35 of Set 2 | victoria
# Processing Record 36 of Set 2 | pisco
# Processing Record 37 of Set 2 | grants pass
# Processing Record 38 of Set 2 | carrollton
# Processing Record 39 of Set 2 | tasiilaq
# Processing Record 40 of Set 2 | grindavik
# Processing Record 41 of Set 2 | new norfolk
# Processing Record 42 of Set 2 | syava
# Processing Record 43 of Set 2 | leningradskiy
# Processing Record 44 of Set 2 | sao filipe
# Processing Record 45 of Set 2 | takhtamygda
# Processing Record 46 of Set 2 | los llanos de aridane
# Processing Record 47 of Set 2 | qadirpur ran
# Processing Record 48 of Set 2 | carupano
# Processing Record 49 of Set 2 | laguna
# Processing Record 50 of Set 2 | kodiak
# Processing Record 1 of Set 3 | grand gaube
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | thompson
# Processing Record 4 of Set 3 | ambilobe
# Processing Record 5 of Set 3 | qaqortoq
# Processing Record 6 of Set 3 | bathsheba
# Processing Record 7 of Set 3 | nanortalik
# Processing Record 8 of Set 3 | saint-joseph
# Processing Record 9 of Set 3 | asayita
# City not found. Skipping...
# Processing Record 10 of Set 3 | bredasdorp
# Processing Record 11 of Set 3 | bengkulu
# Processing Record 12 of Set 3 | provideniya
# Processing Record 13 of Set 3 | lebu
# Processing Record 14 of Set 3 | itarantim
# Processing Record 15 of Set 3 | saint anthony
# Processing Record 16 of Set 3 | minbu
# Processing Record 17 of Set 3 | tiksi
# Processing Record 18 of Set 3 | hervey bay
# Processing Record 19 of Set 3 | butembo
# Processing Record 20 of Set 3 | porto santo
# Processing Record 21 of Set 3 | rabo de peixe
# Processing Record 22 of Set 3 | yellowknife
# Processing Record 23 of Set 3 | khotynets
# Processing Record 24 of Set 3 | hasaki
# Processing Record 25 of Set 3 | ladario
# Processing Record 26 of Set 3 | qaanaaq
# Processing Record 27 of Set 3 | souillac
# Processing Record 28 of Set 3 | marzuq
# Processing Record 29 of Set 3 | cabedelo
# Processing Record 30 of Set 3 | puerto ayora
# Processing Record 31 of Set 3 | iqaluit
# Processing Record 32 of Set 3 | nerchinskiy zavod
# Processing Record 33 of Set 3 | chiang khong
# Processing Record 34 of Set 3 | meiganga
# Processing Record 35 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 3 | chama
# Processing Record 37 of Set 3 | lobanovo
# Processing Record 38 of Set 3 | amahai
# Processing Record 39 of Set 3 | longyearbyen
# Processing Record 40 of Set 3 | grobina
# Processing Record 41 of Set 3 | fort nelson
# Processing Record 42 of Set 3 | khani
# Processing Record 43 of Set 3 | saskylakh
# Processing Record 44 of Set 3 | khatanga
# Processing Record 45 of Set 3 | lompoc
# Processing Record 46 of Set 3 | hami
# Processing Record 47 of Set 3 | sigli
# Processing Record 48 of Set 3 | hobart
# Processing Record 49 of Set 3 | sao paulo de olivenca
# Processing Record 50 of Set 3 | cherskiy
# Processing Record 1 of Set 4 | tupik
# Processing Record 2 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 3 of Set 4 | tver
# Processing Record 4 of Set 4 | antsohihy
# Processing Record 5 of Set 4 | powell
# Processing Record 6 of Set 4 | kedougou
# Processing Record 7 of Set 4 | kulu
# Processing Record 8 of Set 4 | svetlogorsk
# Processing Record 9 of Set 4 | coahuayana
# Processing Record 10 of Set 4 | maghar
# Processing Record 11 of Set 4 | pacifica
# Processing Record 12 of Set 4 | scarborough
# Processing Record 13 of Set 4 | la palma
# Processing Record 14 of Set 4 | shimoda
# Processing Record 15 of Set 4 | ciumeghiu
# Processing Record 16 of Set 4 | mount gambier
# Processing Record 17 of Set 4 | kavieng
# Processing Record 18 of Set 4 | aquidauana
# Processing Record 19 of Set 4 | nador
# Processing Record 20 of Set 4 | cape town
# Processing Record 21 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 4 | trairi
# Processing Record 23 of Set 4 | aberdeen
# Processing Record 24 of Set 4 | te anau
# Processing Record 25 of Set 4 | wadi musa
# Processing Record 26 of Set 4 | porbandar
# Processing Record 27 of Set 4 | shitkino
# Processing Record 28 of Set 4 | novouzensk
# Processing Record 29 of Set 4 | chuy
# Processing Record 30 of Set 4 | daryapur
# Processing Record 31 of Set 4 | mar del plata
# Processing Record 32 of Set 4 | cayenne
# Processing Record 33 of Set 4 | coihaique
# Processing Record 34 of Set 4 | avarua
# Processing Record 35 of Set 4 | san cristobal
# Processing Record 36 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 37 of Set 4 | barrow
# Processing Record 38 of Set 4 | aklavik
# Processing Record 39 of Set 4 | poum
# Processing Record 40 of Set 4 | vardo
# Processing Record 41 of Set 4 | russell
# Processing Record 42 of Set 4 | lucapa
# Processing Record 43 of Set 4 | jamestown
# Processing Record 44 of Set 4 | chirongui
# Processing Record 45 of Set 4 | north battleford
# Processing Record 46 of Set 4 | cabo rojo
# Processing Record 47 of Set 4 | pringsewu
# Processing Record 48 of Set 4 | bahia blanca
# Processing Record 49 of Set 4 | chokurdakh
# Processing Record 50 of Set 4 | cidreira
# Processing Record 1 of Set 5 | muhos
# Processing Record 2 of Set 5 | maldonado
# Processing Record 3 of Set 5 | korla
# Processing Record 4 of Set 5 | agadir
# Processing Record 5 of Set 5 | yumen
# Processing Record 6 of Set 5 | palencia
# Processing Record 7 of Set 5 | beckley
# Processing Record 8 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 5 | pitimbu
# Processing Record 10 of Set 5 | meulaboh
# Processing Record 11 of Set 5 | waingapu
# Processing Record 12 of Set 5 | bethel
# Processing Record 13 of Set 5 | arraial do cabo
# Processing Record 14 of Set 5 | komsomolskiy
# Processing Record 15 of Set 5 | laizhou
# Processing Record 16 of Set 5 | kasama
# Processing Record 17 of Set 5 | klamath falls
# Processing Record 18 of Set 5 | takoradi
# Processing Record 19 of Set 5 | airai
# Processing Record 20 of Set 5 | san pedro de macoris
# Processing Record 21 of Set 5 | geraldton
# Processing Record 22 of Set 5 | starosubkhangulovo
# Processing Record 23 of Set 5 | pangoa
# Processing Record 24 of Set 5 | sheregesh
# Processing Record 25 of Set 5 | deori khas
# Processing Record 26 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 5 | pedernales
# Processing Record 28 of Set 5 | port elizabeth
# Processing Record 29 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 5 | okhotsk
# Processing Record 31 of Set 5 | waipawa
# Processing Record 32 of Set 5 | helena
# Processing Record 33 of Set 5 | sanghar
# Processing Record 34 of Set 5 | bonthe
# Processing Record 35 of Set 5 | nemuro
# Processing Record 36 of Set 5 | donskoy
# Processing Record 37 of Set 5 | parnamirim
# Processing Record 38 of Set 5 | dikson
# Processing Record 39 of Set 5 | luderitz
# Processing Record 40 of Set 5 | pemangkat
# Processing Record 41 of Set 5 | qandala
# Processing Record 42 of Set 5 | kununurra
# Processing Record 43 of Set 5 | sorong
# Processing Record 44 of Set 5 | fortuna
# Processing Record 45 of Set 5 | ewo
# Processing Record 46 of Set 5 | itarema
# Processing Record 47 of Set 5 | basco
# Processing Record 48 of Set 5 | camacupa
# Processing Record 49 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 5 | broken hill
# Processing Record 1 of Set 6 | nalut
# Processing Record 2 of Set 6 | amazar
# Processing Record 3 of Set 6 | melfort
# Processing Record 4 of Set 6 | pangnirtung
# Processing Record 5 of Set 6 | comodoro rivadavia
# Processing Record 6 of Set 6 | kaitangata
# Processing Record 7 of Set 6 | westport
# Processing Record 8 of Set 6 | plettenberg bay
# Processing Record 9 of Set 6 | mikhaylovka
# Processing Record 10 of Set 6 | crotone
# Processing Record 11 of Set 6 | omsukchan
# Processing Record 12 of Set 6 | turan
# Processing Record 13 of Set 6 | maragogi
# Processing Record 14 of Set 6 | jinchang
# Processing Record 15 of Set 6 | college
# Processing Record 16 of Set 6 | rocha
# Processing Record 17 of Set 6 | atar
# Processing Record 18 of Set 6 | khandyga
# Processing Record 19 of Set 6 | amuntai
# Processing Record 20 of Set 6 | lodja
# Processing Record 21 of Set 6 | xuddur
# Processing Record 22 of Set 6 | chauk
# Processing Record 23 of Set 6 | guiratinga
# Processing Record 24 of Set 6 | talnakh
# Processing Record 25 of Set 6 | bowen
# Processing Record 26 of Set 6 | batagay-alyta
# Processing Record 27 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 6 | iquitos
# Processing Record 30 of Set 6 | muravlenko
# Processing Record 31 of Set 6 | shieli
# Processing Record 32 of Set 6 | najran
# Processing Record 33 of Set 6 | saint george
# Processing Record 34 of Set 6 | manica
# Processing Record 35 of Set 6 | padang
# Processing Record 36 of Set 6 | ilulissat
# Processing Record 37 of Set 6 | carnarvon
# Processing Record 38 of Set 6 | menongue
# Processing Record 39 of Set 6 | bhunya
# Processing Record 40 of Set 6 | saint-paul
# Processing Record 41 of Set 6 | langxiang
# Processing Record 42 of Set 6 | brae
# Processing Record 43 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 6 | tuatapere
# Processing Record 45 of Set 6 | maningrida
# Processing Record 46 of Set 6 | san andres
# Processing Record 47 of Set 6 | ipixuna
# Processing Record 48 of Set 6 | beringovskiy
# Processing Record 49 of Set 6 | troitskoye
# Processing Record 50 of Set 6 | aykhal
# Processing Record 1 of Set 7 | salalah
# Processing Record 2 of Set 7 | vila velha
# Processing Record 3 of Set 7 | dudinka
# Processing Record 4 of Set 7 | san pedro
# Processing Record 5 of Set 7 | buala
# Processing Record 6 of Set 7 | sayyan
# Processing Record 7 of Set 7 | pereslavl-zalesskiy
# Processing Record 8 of Set 7 | ngawi
# Processing Record 9 of Set 7 | namatanai
# Processing Record 10 of Set 7 | denpasar
# Processing Record 11 of Set 7 | kampot
# Processing Record 12 of Set 7 | lazaro cardenas
# Processing Record 13 of Set 7 | carauari
# Processing Record 14 of Set 7 | miri
# Processing Record 15 of Set 7 | carutapera
# Processing Record 16 of Set 7 | henties bay
# Processing Record 17 of Set 7 | kutum
# Processing Record 18 of Set 7 | ilebo
# Processing Record 19 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 20 of Set 7 | georgetown
# Processing Record 21 of Set 7 | morecambe
# Processing Record 22 of Set 7 | olinda
# Processing Record 23 of Set 7 | porto novo
# Processing Record 24 of Set 7 | lata
# Processing Record 25 of Set 7 | baruun-urt
# Processing Record 26 of Set 7 | kruisfontein
# Processing Record 27 of Set 7 | anzio
# Processing Record 28 of Set 7 | lodwar
# Processing Record 29 of Set 7 | ojinaga
# Processing Record 30 of Set 7 | dolores
# Processing Record 31 of Set 7 | lamu
# Processing Record 32 of Set 7 | kasongo-lunda
# Processing Record 33 of Set 7 | mindelo
# Processing Record 34 of Set 7 | novaya ladoga
# Processing Record 35 of Set 7 | anadyr
# Processing Record 36 of Set 7 | port augusta
# Processing Record 37 of Set 7 | kawalu
# Processing Record 38 of Set 7 | shenjiamen
# Processing Record 39 of Set 7 | watsa
# Processing Record 40 of Set 7 | marfino
# Processing Record 41 of Set 7 | toamasina
# Processing Record 42 of Set 7 | belaya gora
# Processing Record 43 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 7 | nhulunbuy
# Processing Record 45 of Set 7 | ixtapa
# Processing Record 46 of Set 7 | kirkwall
# Processing Record 47 of Set 7 | khasan
# Processing Record 48 of Set 7 | elizabeth city
# Processing Record 49 of Set 7 | coari
# Processing Record 50 of Set 7 | katsuura
# Processing Record 1 of Set 8 | whitehorse
# Processing Record 2 of Set 8 | synya
# Processing Record 3 of Set 8 | camacha
# Processing Record 4 of Set 8 | acari
# Processing Record 5 of Set 8 | ancud
# Processing Record 6 of Set 8 | cockburn town
# Processing Record 7 of Set 8 | saint-augustin
# Processing Record 8 of Set 8 | teguldet
# Processing Record 9 of Set 8 | husavik
# Processing Record 10 of Set 8 | bara
# Processing Record 11 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 12 of Set 8 | kavarna
# Processing Record 13 of Set 8 | touros
# Processing Record 14 of Set 8 | boulder city
# Processing Record 15 of Set 8 | saquarema
# Processing Record 16 of Set 8 | tramore
# Processing Record 17 of Set 8 | catalina
# Processing Record 18 of Set 8 | esso
# Processing Record 19 of Set 8 | flinders
# Processing Record 20 of Set 8 | paungde
# Processing Record 21 of Set 8 | sambava
# Processing Record 22 of Set 8 | lahaina
# Processing Record 23 of Set 8 | hambantota
# Processing Record 24 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 8 | tanout
# Processing Record 26 of Set 8 | kayes
# Processing Record 27 of Set 8 | orange cove
# Processing Record 28 of Set 8 | asau
# Processing Record 29 of Set 8 | byron bay
# Processing Record 30 of Set 8 | jeremie
# Processing Record 31 of Set 8 | portland
# Processing Record 32 of Set 8 | rorvik
# Processing Record 33 of Set 8 | bend
# Processing Record 34 of Set 8 | topeka
# Processing Record 35 of Set 8 | dukat
# Processing Record 36 of Set 8 | littlehampton
# Processing Record 37 of Set 8 | uyemskiy
# Processing Record 38 of Set 8 | umba
# Processing Record 39 of Set 8 | panacan
# Processing Record 40 of Set 8 | champerico
# Processing Record 41 of Set 8 | alofi
# Processing Record 42 of Set 8 | saint-pierre
# Processing Record 43 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 44 of Set 8 | vila franca do campo
# Processing Record 45 of Set 8 | huangzhai
# Processing Record 46 of Set 8 | rtishchevo
# Processing Record 47 of Set 8 | sri aman
# Processing Record 48 of Set 8 | izumo
# Processing Record 49 of Set 8 | ballina
# Processing Record 50 of Set 8 | bileca
# Processing Record 1 of Set 9 | muros
# Processing Record 2 of Set 9 | mount isa
# Processing Record 3 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 9 | borogontsy
# Processing Record 5 of Set 9 | guilin
# Processing Record 6 of Set 9 | ketchikan
# Processing Record 7 of Set 9 | jalu
# Processing Record 8 of Set 9 | sioux lookout
# Processing Record 9 of Set 9 | coamo
# Processing Record 10 of Set 9 | shubarshi
# Processing Record 11 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 9 | yatou
# Processing Record 13 of Set 9 | mogadishu
# Processing Record 14 of Set 9 | sobolevo
# Processing Record 15 of Set 9 | akhaldaba
# Processing Record 16 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 17 of Set 9 | johnson city
# Processing Record 18 of Set 9 | awbari
# Processing Record 19 of Set 9 | lengshuijiang
# Processing Record 20 of Set 9 | wanganui
# Processing Record 21 of Set 9 | wenatchee
# Processing Record 22 of Set 9 | falmouth
# Processing Record 23 of Set 9 | karratha
# Processing Record 24 of Set 9 | the valley
# Processing Record 25 of Set 9 | mecca
# Processing Record 26 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 9 | ahipara
# Processing Record 28 of Set 9 | lianzhou
# Processing Record 29 of Set 9 | kenai
# Processing Record 30 of Set 9 | xiaoweizhai
# Processing Record 31 of Set 9 | burica
# City not found. Skipping...
# Processing Record 32 of Set 9 | dunmore town
# Processing Record 33 of Set 9 | hualmay
# Processing Record 34 of Set 9 | rio grande
# Processing Record 35 of Set 9 | boralday
# Processing Record 36 of Set 9 | cantapoy
# Processing Record 37 of Set 9 | atambua
# Processing Record 38 of Set 9 | lac du bonnet
# Processing Record 39 of Set 9 | milkovo
# Processing Record 40 of Set 9 | taunggyi
# Processing Record 41 of Set 9 | yian
# City not found. Skipping...
# Processing Record 42 of Set 9 | inirida
# Processing Record 43 of Set 9 | itoman
# Processing Record 44 of Set 9 | prince rupert
# Processing Record 45 of Set 9 | barcelos
# Processing Record 46 of Set 9 | agadez
# Processing Record 47 of Set 9 | creel
# Processing Record 48 of Set 9 | belem de sao francisco
# Processing Record 49 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 9 | walvis bay
# Processing Record 1 of Set 10 | kargasok
# Processing Record 2 of Set 10 | cururupu
# Processing Record 3 of Set 10 | kungurtug
# Processing Record 4 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 10 | coruripe
# Processing Record 6 of Set 10 | eureka
# Processing Record 7 of Set 10 | esperance
# Processing Record 8 of Set 10 | kodinsk
# Processing Record 9 of Set 10 | necochea
# Processing Record 10 of Set 10 | aripuana
# Processing Record 11 of Set 10 | uyuni
# Processing Record 12 of Set 10 | turayf
# Processing Record 13 of Set 10 | oconomowoc
# Processing Record 14 of Set 10 | nichinan
# Processing Record 15 of Set 10 | mkushi
# Processing Record 16 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 17 of Set 10 | ushtobe
# Processing Record 18 of Set 10 | novouralsk
# Processing Record 19 of Set 10 | batsfjord
# Processing Record 20 of Set 10 | athmallik
# Processing Record 21 of Set 10 | berlevag
# Processing Record 22 of Set 10 | boguchar
# Processing Record 23 of Set 10 | pechenga
# Processing Record 24 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 25 of Set 10 | sembe
# Processing Record 26 of Set 10 | corrente
# Processing Record 27 of Set 10 | constantine
# Processing Record 28 of Set 10 | hendijan
# City not found. Skipping...
# Processing Record 29 of Set 10 | ocho rios
# Processing Record 30 of Set 10 | port hedland
# Processing Record 31 of Set 10 | redlands
# Processing Record 32 of Set 10 | kushmurun
# Processing Record 33 of Set 10 | sao joao da barra
# Processing Record 34 of Set 10 | tazovskiy
# Processing Record 35 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 36 of Set 10 | sugar hill
# Processing Record 37 of Set 10 | pedasi
# Processing Record 38 of Set 10 | haines junction
# Processing Record 39 of Set 10 | payo
# Processing Record 40 of Set 10 | red bluff
# Processing Record 41 of Set 10 | tura
# Processing Record 42 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 10 | arroio dos ratos
# Processing Record 44 of Set 10 | ormara
# Processing Record 45 of Set 10 | hobyo
# Processing Record 46 of Set 10 | opuwo
# Processing Record 47 of Set 10 | san isidro
# Processing Record 48 of Set 10 | chalus
# Processing Record 49 of Set 10 | roald
# Processing Record 50 of Set 10 | ilinskiy
# Processing Record 1 of Set 11 | charters towers
# Processing Record 2 of Set 11 | jiayuguan
# Processing Record 3 of Set 11 | lasa
# Processing Record 4 of Set 11 | linxia
# Processing Record 5 of Set 11 | emerald
# Processing Record 6 of Set 11 | konyshevka
# Processing Record 7 of Set 11 | fairbanks
# Processing Record 8 of Set 11 | mao
# Processing Record 9 of Set 11 | praia da vitoria
# Processing Record 10 of Set 11 | midland
# Processing Record 11 of Set 11 | nacimiento
# Processing Record 12 of Set 11 | kirakira
# Processing Record 13 of Set 11 | puerto escondido
# Processing Record 14 of Set 11 | artyom
# Processing Record 15 of Set 11 | half moon bay
# Processing Record 16 of Set 11 | aswan
# Processing Record 17 of Set 11 | port ellen
# City not found. Skipping...
# Processing Record 18 of Set 11 | polunochnoye
# Processing Record 19 of Set 11 | frederikshavn
# Processing Record 20 of Set 11 | port hardy
# Processing Record 21 of Set 11 | bobon
# Processing Record 22 of Set 11 | yerbogachen
# Processing Record 23 of Set 11 | zhuhai
# Processing Record 24 of Set 11 | pasni
# Processing Record 25 of Set 11 | haradok
# Processing Record 26 of Set 11 | palasa
# Processing Record 27 of Set 11 | strezhevoy
# Processing Record 28 of Set 11 | boa vista
# Processing Record 29 of Set 11 | catamarca
# Processing Record 30 of Set 11 | seydisehir
# Processing Record 31 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 32 of Set 11 | gubbio
# Processing Record 33 of Set 11 | mehamn
# Processing Record 34 of Set 11 | nanticoke
# Processing Record 35 of Set 11 | otradnoye
# Processing Record 36 of Set 11 | bereda
# Processing Record 37 of Set 11 | san angelo
# Processing Record 38 of Set 11 | havoysund
# Processing Record 39 of Set 11 | bilibino
# Processing Record 40 of Set 11 | murcia
# Processing Record 41 of Set 11 | avera
# Processing Record 42 of Set 11 | kibre mengist
# Processing Record 43 of Set 11 | muisne
# Processing Record 44 of Set 11 | panguna
# Processing Record 45 of Set 11 | moerai
# Processing Record 46 of Set 11 | garowe
# Processing Record 47 of Set 11 | dzaoudzi
# Processing Record 48 of Set 11 | tacuarembo
# Processing Record 49 of Set 11 | verkhnedneprovskiy
# Processing Record 50 of Set 11 | solnechnyy
# Processing Record 1 of Set 12 | cache creek
# Processing Record 2 of Set 12 | susangerd
# Processing Record 3 of Set 12 | pangkalanbuun
# Processing Record 4 of Set 12 | lubumbashi
# Processing Record 5 of Set 12 | davidson
# Processing Record 6 of Set 12 | kukmor
# Processing Record 7 of Set 12 | sinnamary
# Processing Record 8 of Set 12 | canton
# Processing Record 9 of Set 12 | baykit
# Processing Record 10 of Set 12 | sabang
# Processing Record 11 of Set 12 | elbistan
# Processing Record 12 of Set 12 | abaete
# Processing Record 13 of Set 12 | masvingo
# Processing Record 14 of Set 12 | kyzyl-suu
# Processing Record 15 of Set 12 | zhifang
# Processing Record 16 of Set 12 | tornio
# Processing Record 17 of Set 12 | narsaq
# Processing Record 18 of Set 12 | jackson
# Processing Record 19 of Set 12 | constitucion
# Processing Record 20 of Set 12 | biak
# Processing Record 21 of Set 12 | xiaoshan
# Processing Record 22 of Set 12 | nome
# Processing Record 23 of Set 12 | nioro
# Processing Record 24 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 25 of Set 12 | kahului
# Processing Record 26 of Set 12 | antofagasta
# Processing Record 27 of Set 12 | mangai
# Processing Record 28 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 12 | chicama
# Processing Record 30 of Set 12 | virginia beach
# Processing Record 31 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 12 | gorbehaza
# Processing Record 33 of Set 12 | labuhan
# Processing Record 34 of Set 12 | yulara
# Processing Record 35 of Set 12 | winchester
# Processing Record 36 of Set 12 | saint joseph
# Processing Record 37 of Set 12 | varhaug
# Processing Record 38 of Set 12 | port shepstone
# Processing Record 39 of Set 12 | santa cruz
# Processing Record 40 of Set 12 | williams lake
# Processing Record 41 of Set 12 | kastamonu
# Processing Record 42 of Set 12 | kanungu
# Processing Record 43 of Set 12 | zhanaozen
# Processing Record 44 of Set 12 | requena
# Processing Record 45 of Set 12 | baisha
# Processing Record 46 of Set 12 | leh
# Processing Record 47 of Set 12 | enumclaw
# Processing Record 48 of Set 12 | ambon
# Processing Record 49 of Set 12 | hohhot
# Processing Record 50 of Set 12 | dzilam gonzalez
# Processing Record 1 of Set 13 | kieta
# Processing Record 2 of Set 13 | houston
# Processing Record 3 of Set 13 | kitui
# Processing Record 4 of Set 13 | sochi
# Processing Record 5 of Set 13 | bulaevo
# Processing Record 6 of Set 13 | dingzhou
# Processing Record 7 of Set 13 | la ronge
# Processing Record 8 of Set 13 | vallenar
# Processing Record 9 of Set 13 | northampton
# Processing Record 10 of Set 13 | alenquer
# Processing Record 11 of Set 13 | chardara
# Processing Record 12 of Set 13 | ingham
# Processing Record 13 of Set 13 | wonthaggi
# Processing Record 14 of Set 13 | benguela
# Processing Record 15 of Set 13 | petropavl
# Processing Record 16 of Set 13 | gamba
# Processing Record 17 of Set 13 | lodeynoye pole
# Processing Record 18 of Set 13 | deputatskiy
# Processing Record 19 of Set 13 | coquimbo
# Processing Record 20 of Set 13 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 21 of Set 13 | mantua
# Processing Record 22 of Set 13 | jubayl
# City not found. Skipping...
# Processing Record 23 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 24 of Set 13 | grafton
# Processing Record 25 of Set 13 | grigoropolisskaya
# Processing Record 26 of Set 13 | hammerfest
# Processing Record 27 of Set 13 | gazimurskiy zavod
# Processing Record 28 of Set 13 | ishinomaki
# Processing Record 29 of Set 13 | makat
# Processing Record 30 of Set 13 | parfenyevo
# Processing Record 31 of Set 13 | benoy
# Processing Record 32 of Set 13 | lohja
# Processing Record 33 of Set 13 | margate
# Processing Record 34 of Set 13 | pochutla
# Processing Record 35 of Set 13 | kalmunai
# Processing Record 36 of Set 13 | maumere
# Processing Record 37 of Set 13 | sandy bay
# Processing Record 38 of Set 13 | caravelas
# Processing Record 39 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 40 of Set 13 | beberibe
# Processing Record 41 of Set 13 | xichang
# Processing Record 42 of Set 13 | leshukonskoye
# Processing Record 43 of Set 13 | presidente prudente
# Processing Record 44 of Set 13 | richards bay
# Processing Record 45 of Set 13 | zhangjiakou
# Processing Record 46 of Set 13 | northam
# Processing Record 47 of Set 13 | mombetsu
# Processing Record 48 of Set 13 | kankaanpaa
# Processing Record 49 of Set 13 | camargo
# Processing Record 50 of Set 13 | raudeberg
# Processing Record 1 of Set 14 | antigonish
# Processing Record 2 of Set 14 | ko samui
# Processing Record 3 of Set 14 | zhezkazgan
# Processing Record 4 of Set 14 | diego de almagro
# Processing Record 5 of Set 14 | acapulco
# Processing Record 6 of Set 14 | norrtalje
# Processing Record 7 of Set 14 | bucerias
# Processing Record 8 of Set 14 | gorodovikovsk
# Processing Record 9 of Set 14 | yulin
# Processing Record 10 of Set 14 | erzin
# Processing Record 11 of Set 14 | honiara
# Processing Record 12 of Set 14 | jingcheng
# Processing Record 13 of Set 14 | nexo
# Processing Record 14 of Set 14 | maubin
# Processing Record 15 of Set 14 | viksoyri
# City not found. Skipping...
# Processing Record 16 of Set 14 | gat
# Processing Record 17 of Set 14 | manono
# Processing Record 18 of Set 14 | dubai
# Processing Record 19 of Set 14 | ntcheu
# Processing Record 20 of Set 14 | darnah
# Processing Record 21 of Set 14 | sola
# Processing Record 22 of Set 14 | port lincoln
# Processing Record 23 of Set 14 | dumas
# Processing Record 24 of Set 14 | diamantino
# Processing Record 25 of Set 14 | bilma
# Processing Record 26 of Set 14 | apac
# Processing Record 27 of Set 14 | chumphon
# Processing Record 28 of Set 14 | lysyanka
# Processing Record 29 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 14 | chervone
# Processing Record 31 of Set 14 | rottingdean
# Processing Record 32 of Set 14 | gizo
# Processing Record 33 of Set 14 | san julian
# Processing Record 34 of Set 14 | tual
# Processing Record 35 of Set 14 | jacmel
# Processing Record 36 of Set 14 | abu dhabi
# Processing Record 37 of Set 14 | lagoa
# Processing Record 38 of Set 14 | peoria
# Processing Record 39 of Set 14 | ola
# Processing Record 40 of Set 14 | artigas
# Processing Record 41 of Set 14 | iguape
# Processing Record 42 of Set 14 | inhambane
# Processing Record 43 of Set 14 | tiffin
# Processing Record 44 of Set 14 | beloha
# Processing Record 45 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 46 of Set 14 | aloleng
# Processing Record 47 of Set 14 | katobu
# Processing Record 48 of Set 14 | hangu
# Processing Record 49 of Set 14 | yushan
# Processing Record 50 of Set 14 | cape coast
# Processing Record 1 of Set 15 | maxixe
# Processing Record 2 of Set 15 | lukulu
# Processing Record 3 of Set 15 | qasigiannguit
# Processing Record 4 of Set 15 | ranong
# Processing Record 5 of Set 15 | ponta do sol
# Processing Record 6 of Set 15 | voitsberg
# Processing Record 7 of Set 15 | mareeba
# Processing Record 8 of Set 15 | balabac
# Processing Record 9 of Set 15 | lavrentiya
# Processing Record 10 of Set 15 | port blair
# Processing Record 11 of Set 15 | oktyabrskoye
# Processing Record 12 of Set 15 | havelock
# Processing Record 13 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 14 of Set 15 | rio gallegos
# Processing Record 15 of Set 15 | gambiran
# Processing Record 16 of Set 15 | hatfield
# Processing Record 17 of Set 15 | tarko-sale
# Processing Record 18 of Set 15 | vanimo
# Processing Record 19 of Set 15 | gobabis
# Processing Record 20 of Set 15 | toftir
# City not found. Skipping...
# Processing Record 21 of Set 15 | mozarlandia
# Processing Record 22 of Set 15 | cartagena
# Processing Record 23 of Set 15 | nefteyugansk
# Processing Record 24 of Set 15 | lakes entrance
# Processing Record 25 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 26 of Set 15 | adre
# Processing Record 27 of Set 15 | san luis
# Processing Record 28 of Set 15 | progreso
# Processing Record 29 of Set 15 | katherine
# Processing Record 30 of Set 15 | oranjemund
# Processing Record 31 of Set 15 | ovalle
# Processing Record 32 of Set 15 | bonavista
# Processing Record 33 of Set 15 | ilo
# Processing Record 34 of Set 15 | sterling
# Processing Record 35 of Set 15 | phan thiet
# Processing Record 36 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 37 of Set 15 | micheweni
# Processing Record 38 of Set 15 | phuket
# Processing Record 39 of Set 15 | namibe
# Processing Record 40 of Set 15 | saint-francois
# Processing Record 41 of Set 15 | broome
# Processing Record 42 of Set 15 | amilly
# Processing Record 43 of Set 15 | la ligua
# Processing Record 44 of Set 15 | karla
# Processing Record 45 of Set 15 | talas
# Processing Record 46 of Set 15 | baherden
# Processing Record 47 of Set 15 | alanya
# Processing Record 48 of Set 15 | mutoko
# Processing Record 49 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 16 | knysna
# Processing Record 2 of Set 16 | rivera
# Processing Record 3 of Set 16 | cap malheureux
# Processing Record 4 of Set 16 | ouango
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 698

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
print (city_data_df.head(10))
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Svetlyy  54.6750   20.1347     30.25        93         100
# 1         Clifton  40.8584  -74.1638     33.84        36           0
# 2           Sitka  57.0531 -135.3300     48.09        81         100
# 3       Busselton -33.6500  115.3333     55.58        65           0
# 4  Cabo San Lucas  22.8909 -109.9124     80.62        62           1
# 5        Lorengau  -2.0226  147.2712     84.92        63          86
# 6          Faanui -16.4833 -151.7500     78.39        74          61
# 7       Mossendjo  -2.9506   12.7261     68.23       100         100
# 8    Punta Arenas -53.1500  -70.9167     53.71        54          75
# 9  Chernyshevskiy  63.0128  112.4714    -23.13       100          77
#
#    Wind Speed Country                 Date
# 0       14.00      RU  2022-11-20 22:47:25
# 1       13.80      US  2022-11-20 22:47:25
# 2        5.75      US  2022-11-20 22:47:26
# 3       13.53      AU  2022-11-20 22:47:26
# 4        7.40      MX  2022-11-20 22:44:23
# 5        9.62      PG  2022-11-20 22:46:31
# 6       18.23      PF  2022-11-20 22:40:37
# 7        3.04      CG  2022-11-20 22:47:26
# 8       21.85      CL  2022-11-20 22:47:26
# 9        1.61      RU  2022-11-20 22:47:27

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["column2", "column4", "column1"]

# Recreate the DataFrame by using the new column order
city_data_df = df[new_column_order]

# Display sample data
city_data_df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38000\677444196.py in <module>
#       4
#       5 # Recreate the DataFrame by using the new column order
# ----> 6 city_data_df = df[new_column_order]
#       7
#       8 # Display sample data
#
# NameError: name 'df' is not defined

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date           object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Module 6 Challenge/cities.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
